# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="150" height="200"/></a>
# <pre>
# <center><b><h2> Python for Data Science - 2305CS303 </b></center>
# <center><b><h2>Lab - 1</b></center>
# <left><b><h3>Roll No. : 122</b></left>
# <left><b><h3>Name : Yatharth Sanghavi</b></left>
# <pre>

# %% [markdown]
# ### 1. WAP to print “Hello World”.

# %%
print("hello World")
# Out:
# hello World

# %% [markdown]
# ### 2. WAP to print your address i) using single print ii) using multiple print.

# %%
print("13, Plot No.56, Castle House, Sher-e-punjab Society,mahakali, Andheri")
print("""13, 
Plot No.56,
Castle House, 
Sher-e-punjab Society,
mahakali, 
Andheri""")
# Out:
# 13, Plot No.56, Castle House, Sher-e-punjab Society,mahakali, Andheri
# 13,
# Plot No.56,
# Castle House,
# Sher-e-punjab Society,
# mahakali,
# Andheri

# %% [markdown]
# ### 3. WAP to print addition of 2 numbers (without input function).

# %%
a=int(input("Enter a: "))
b=int(input("enter b: "))
print(a+b)
# Out:
# Enter a:  1
# enter b:  2
# 3

# %% [markdown]
# ### 4. WAP to calculate and print average of 2 numbers (without input function).

# %%
a=int(input("Enter a: "))
b=int(input("enter b: "))
print((a+b)/2)
# Out:
# Enter a:  10
# enter b:  20
# 15.0

# %% [markdown]
# ### 5. WAP to add two number entered by user.

# %%
a=int(input("Enter a: "))
b=int(input("enter b: "))
print(a+b)
# Out:
# Enter a:  10
# enter b:  20
# 30

# %% [markdown]
# ### 6. WAP to calculate area of circle.

# %%
a=int(input("enter r: "))
print(3.14*(a*a))
# Out:
# enter r:  12
# 452.16

# %% [markdown]
# ### 7. Purposefully raise Indentation Error and Correct it.

# %%
if True:
print("helo")
if True:
    print("hello")
# Out:
#   Cell In[4], line 2
#     print("helo")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# ### 8. WAP to calculate simple interest.

# %%
p=int(input("enter p: "))
r=int(input("enter r: "))
t=int(input("enter t: "))
print((p*r*t)/100)
# Out:
# enter p:  10
# enter r:  20
# enter t:  30
# 60.0

# %% [markdown]
# ### 9. WAP Calculate Area and Circumference of Circle.

# %%
a=int(input("enter r: "))
print(3.14*(a*a))
print(2*3.14*a)
# Out:
# enter r:  10
# 314.0
# 62.800000000000004

# %% [markdown]
# ### 10. WAP to print Multiplication table of given number.

# %%
a=int(input("enter a: "))
for i in range(1,11):
    print(i*a)
# Out:
# enter a:  5
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
### 11. WAP to calculate Area of Triangle. (hint: a = h*b*0.5)

# %%
b=int(input("enter b: "))
h=int(input("enter h: "))
print(1/2*(b*h))
# Out:
# enter b:  10
# enter h:  20
# 100.0

# %% [markdown]
# ### 12. WAP to convert Degree to Fahrenheit and vice versa.

# %%
b=int(input("enter b: "))
print((b*(9/5))+32)
f=int(input("enter f: "))
print((f-32)*(5/9))
# Out:
# enter b:  10
# 50.0
# enter f:  20
# -6.666666666666667

# %% [markdown]
# ### 13.WAP to calculate total marks and Percentage.

# %%
a=int(input("enter a"))
b=int(input("enter b"))
c=int(input("enter c"))
d=int(input("enter d"))
e=int(input("enter e"))
total=a+b+c+d+e
per=(total/100)*5
print(total)
print(per)
# Out:
# enter a 10
# enter b 20
# enter c 30
# enter d 4
# enter e 50
# 114
# 5.699999999999999

# %% [markdown]
# ### 14. Calculate Gross Salary

# %%
a=int(input("enter base salary"))
hdr=(a*10)/100
da=(a*8)/100
print(a+hdr+da)
# Out:
# enter base salary 100
# 118.0

# %% [markdown]
# ### 15.Swap Two number

# %%
b=int(input("enter b: "))
h=int(input("enter h: "))
temp=b
b=h
h=temp
print(b,h)
# Out:
# enter b:  10
# enter h:  20
# 20 10

# %% [markdown]
# ### 16.Swap Two number without using third variable

# %%
b=int(input("enter b: "))
h=int(input("enter h: "))
b,h=h,b
print(b,h)
# Out:
# enter b:  10
# enter h:  20
# 20 10

# %% [markdown]
# ### 17. Convert total second into Hours,Minutes and Second

# %%
s=int(input("enter total second"))
h=int(s/3600)
m=int((s%3600)/60)
s=int(s%60)
print(h,m,s)
# Out:
# enter total second 1500
# 0 25 0

# %% [markdown]
# ### 17. Convert Number of days into Years, Months, days

# %%
d=int(input("enter total days"))
y=int(d/365)
m=int((d%365)/30)
d=int((d%365)%30)
print(y,m,d)
# Out:
# enter total days 372
# 1 0 7
