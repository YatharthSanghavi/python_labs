# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="150" height="200"/></a>
# <pre>
# <center><b><h2> Python for Data Science - 2305CS303 </b></center>
# <center><b><h2>Lab - 8</b></center>
# <left><b><h3>Roll No. : 122</b></left>
# <left><b><h3>Name : Yatharth Sanghavi</b></left>
# <pre>

# %% [markdown]
# ### 01) Write a function to calculate BMI given mass and height. (BMI = mass/h**2)

# %%
def bmi(mass,height):
    return mass/(height**2)
    
mass=100
height=2
print(bmi(mass,height))
# Out:
# 25.0

# %% [markdown]
# ### 02) Write a function that add first n numbers.

# %%
def addn(n):
    return sum(range(1,n+1))
addn(10)
# Out:
# 55

# %% [markdown]
# ### 03) Write a function that returns 1 if the given number is Prime or 0 otherwise.

# %%
def prime(n):
    for i in range(2,n):
        if n%i==0:
            return 0
    else:
        return 1
r=prime(11)
if r==1:
    print("number is prime")
else:
    print("number is not prime")
# Out:
# number is prime

# %% [markdown]
# ### 04) Write a function that returns the list of Prime numbers between given two numbers.

# %%
def prime(n,n2):
    result=[]
    for i in range(n,n2+1):
        for j in range(2,i):
            if i%j==0:
                break
        else:
            result.append(i)
    return result
n=1
n2=10
result=prime(n,n2)
result
# Out:
# [1, 2, 3, 5, 7]

# %% [markdown]
# ### 05) Write a function that returns True if the given string is Palindrome or False otherwise.

# %%
def palindrome(s):
    return s == s[::-1]
r=palindrome("nayan")
r
# Out:
# True

# %% [markdown]
# ### 06) Write a function that returns the sum of all the elements of the list.

# %%
def suml(l):
    return sum(l)
l=[1,2,3,4,5]
r=suml(l)
r
# Out:
# 15

# %% [markdown]
# ### 07) Write a function to calculate the sum of the first element of each tuples inside the list.

# %%
l=[(1,2,3),(1,2,3),(1,2,3)]
r=0
for i in range(len(l)):
    r+=l[i][0]
r
# Out:
# 3

# %% [markdown]
# ### 08) Write a recursive function to find nth term of Fibonacci Series.

# %%
def fibonacci(n):
    l=[0,1]
    for i in range(n):
        p=l[-1]
        pn=l[-2]
        r=p+pn
        l.append(r)
    return l[n]
n=5
print(fibonacci(n))
# Out:
# 5

# %% [markdown]
# ### 09) Write a function to get the name of the student based on the given rollno.
# #### Example: Given dict1 = {101:'Ajay', 102:'Rahul', 103:'Jay', 104:'Pooja'} find name of student whose rollno = 103

# %%
dict1 = {101:'Ajay', 102:'Rahul', 103:'Jay', 104:'Pooja'}
rollno = 103
print(dict1.get(rollno))
# Out:
# Jay

# %% [markdown]
# ### 10) Write a function to get the sum of the scores ending with zero.
# #### Example : scores = [200, 456, 300, 100, 234, 678]
# #### Ans = 200 + 300 + 100 = 600

# %%
def sum_endzero(scores):
    r=0
    for i in scores:
        if i%10==0:
            r+=i
    return r
scores = [200, 456, 300, 100, 234, 678]
print(sum_endzero(scores))
# Out:
# 600

# %% [markdown]
# ### 11) Write a function to invert a given Dictionary.
# #### hint: keys to values & values to keys
# #### Before : {'a': 10, 'b':20, 'c':30, 'd':40}
# #### After : {10:'a', 20:'b', 30:'c', 40:'d'}

# %%
d= {'a': 10, 'b':20, 'c':30, 'd':40}
r={v:k for k,v in d.items()}
r
# Out:
# {10: 'a', 20: 'b', 30: 'c', 40: 'd'}

# %% [markdown]
# ### 12) Write a function that returns the number of uppercase and lowercase letters in the given string.
# #### example : Input : s1 = AbcDEfgh ,Ouptput : no_upper = 3, no_lower = 5

# %%
s1 = "AbcDEfgh"
no_upper=0
no_lower=0
for i in s1:
    if i.isupper():
        no_upper+=1
    elif i.islower():
        no_lower+=1
print("no_upper=",no_upper)
print("no_lower=",no_lower)
# Out:
# no_upper= 3
# no_lower= 5

# %% [markdown]
# ### 13) Write a lambda function to get smallest number from the given two numbers.

# %%
n=10
n2=5
r=(lambda n,n2:n if n<n2 else n2)(n,n2)
print(r)
# Out:
# 5

# %% [markdown]
# ### 14) For the given list of names of students, extract the names having more that 7 characters. Use filter().

# %%
student=['rahul','ram','ravan','krish','sachin','ramanandan']
r= list(filter(lambda s:len(s)>=7,student))
r
# Out:
# ['ramanandan']

# %% [markdown]
# ### 15) For the given list of names of students, convert the first letter of all the names into uppercase. use map().

# %%
student=['rahul','ram','ravan','krish','sachin','ramanandan']
r=list(map(lambda s:s.title(),student))
r
# Out:
# ['Rahul', 'Ram', 'Ravan', 'Krish', 'Sachin', 'Ramanandan']

# %% [markdown]
# ### 16) Write udfs to call the functions with following types of arguments:
# 1. Positional Arguments
# 2. Keyword Arguments
# 3. Default Arguments
# 4. Variable Legngth Positional(*args) & variable length Keyword Arguments (**kwargs)
# 5. Keyword-Only & Positional Only Arguments

# %%
def Positional(a,b,c):
    print(a,b,c)
def Keyword(a,b,c):
    print(a,b,c)
def Default(c):
    print(c)
def VariablelP(*c):
    print(c)
def VariablelK(**k):
    print(k)
def keywordo(*,a,b,c):
    print(a,b,c)
def positionalo(a,b,c,/):
    print(a,b,c)

Positional(1,2,3)
Keyword(2,b=3,c=1)
Default(4)
VariablelP(1,2,3,4)
VariablelK(a=10,b=20,c=20)
keywordo(a=0,b=0,c=0)
positionalo(1,2,3)
# Out:
# 1 2 3
# 2 3 1
# 4
# (1, 2, 3, 4)
# {'a': 10, 'b': 20, 'c': 20}
# 0 0 0
# 1 2 3
